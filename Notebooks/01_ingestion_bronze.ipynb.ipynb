# %%
df = spark.read.option("header", "true").parquet("/Volumes/workspace/nyc_taxi/yellow_trips_01_2025/yellow_tripdata_2025-01.parquet")
#df.display()
#df.tail(5)
df.write.format("delta").mode("overwrite").saveAsTable("bronze_taxi_trips")

# %%
# %sql
DESCRIBE HISTORY bronze_taxi_trips;
SELECT COUNT(*) AS BRONZE_TAXI_TRIPS_TBL_RCD_COUNT FROM bronze_taxi_trips;
